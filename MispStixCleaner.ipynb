# %% [markdown]
# ## Lettura file json

# %%
import json

def read_stix_json(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except Exception as e:
        print(f"Errore nella lettura del file: {e}")
        return None

def print_stix_data(stix_data):
    if stix_data is not None:
        # Stampa il contenuto del file JSON in modo leggibile
        print(json.dumps(stix_data, indent=4))
    else:
        print("Nessun dato da mostrare.")

if __name__ == "__main__":
    file_path = '/content/IranianDisinformation.json'  #percorso del file JSON STIX
    stix_data = read_stix_json(file_path)
    print_stix_data(stix_data)
# Out:
# {
#     "type": "bundle",
#     "id": "bundle--508e8488-2c6d-4631-a13b-4b1f4d298e7f",
#     "objects": [
#         {
#             "type": "identity",
#             "spec_version": "2.1",
#             "id": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:26:51.000Z",
#             "modified": "2024-06-07T16:26:51.000Z",
#             "name": "Leonardo Sole",
#             "identity_class": "organization"
#         },
#         {
#             "type": "grouping",
#             "spec_version": "2.1",
#             "id": "grouping--2c814348-0d1a-48a2-847a-1504248def9d",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:26:51.000Z",
#             "modified": "2024-06-07T16:26:51.000Z",
#             "name": "Global-Iranian-Disinformation-Operation",
#             "context": "suspicious-activity",
#             "object_refs": [
#                 "x-misp-galaxy-cluster--a2355290-e41e-5210-b03c-6ef88d4b61c2",
#                 "x-misp-galaxy-cluster--9039269a-4975-52f8-92a8-f142978ffcef",
#                 "x-misp-galaxy-cluster--7bbdfe14-8294-54f7-9842-449f2db17a90",
#                 "x-misp-galaxy-cluster--bff9c590-c655-5c15-ae4d-13d353a0d9a4",
#                 "x-misp-galaxy-cluster--7828596a-f1b5-563c-bd40-4a876b5cec58",
#                 "x-misp-galaxy-cluster--d9bbfde8-dda3-5f20-a9ed-fbf021ecd8c1",
#                 "x-misp-galaxy-cluster--4896a448-be51-5423-89cd-efb6444b1c75",
#                 "x-misp-galaxy-cluster--f1d52ce1-f431-5732-a071-215cb3306f3e",
#                 "x-misp-galaxy-cluster--b9dceeab-f5d8-50ae-ad8a-365d77fc4a3d",
#                 "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#                 "indicator--2daab435-3a94-4508-b085-eb25f3df06a3",
#                 "indicator--1df640d4-465e-436d-a195-2ef830bac6dd",
#                 "x-misp-object--531e2764-4e78-414f-8111-baec812fdbc0",
#                 "indicator--38005a75-0d99-449c-b7de-8a8e7cdae262",
#                 "indicator--5e4718d5-1e48-4447-a36d-a3d073898292",
#                 "x-misp-galaxy-cluster--7f984091-41b3-5e8f-b723-1d5eb9150d1d",
#                 "x-misp-galaxy-cluster--79364323-1d9e-5e29-8bd8-d0bc7bf32f30",
#                 "x-misp-galaxy-cluster--012be2cf-7aed-5ac4-8fb5-ad7ffff73ea0",
#                 "x-misp-galaxy-cluster--324248a7-3a0c-5689-8f0e-770d6d6f2dd7",
#                 "x-misp-galaxy-cluster--e41d7f0f-d913-5973-b8a3-385b39e78ebd",
#                 "x-misp-galaxy-cluster--9c655aa6-1474-5ab9-8eff-519df00fe41b",
#                 "observed-data--999a81ab-f568-431a-98e7-c110a3005ec9",
#                 "user-account--999a81ab-f568-431a-98e7-c110a3005ec9",
#                 "observed-data--9a94542d-3b31-4fe4-821a-b9b44020f047",
#                 "user-account--9a94542d-3b31-4fe4-821a-b9b44020f047",
#                 "indicator--1556485a-a0e6-47cb-9aa5-c799f09989c5",
#                 "x-misp-object--27696487-d5c8-4706-9513-f911bdad923f",
#                 "relationship--e290f2e3-1043-4456-8eb8-7fcde31372d7",
#                 "relationship--c1b67dba-5904-4d8b-a012-a6aa3fd84897",
#                 "relationship--81954bde-3f01-4d21-b3f9-b1abd07c191d",
#                 "relationship--241a05e8-47d4-40cf-9c8d-a9a0eaeba563",
#                 "relationship--a9ab0538-107c-44d5-9888-df9cfddb7c8c",
#                 "relationship--7e97649d-ec2b-4526-ba89-dca02fcf715a",
#                 "relationship--023a5c94-4400-4914-a7ae-a7041d75acde",
#                 "relationship--ab400298-d565-4cdc-ad5c-8293c7dc2862",
#                 "relationship--fadb73d0-d449-4efe-93fd-5a5ab708ff9e",
#                 "relationship--94ecae7b-2635-493b-b7f0-2a8a0efd08b7",
#                 "relationship--3e44a782-80c0-40da-8982-e59f374fc681",
#                 "relationship--6e9815cb-245c-4ee5-85a8-97e476da6fcf",
#                 "relationship--84066482-d5f2-47d7-b538-2289526f5c5c",
#                 "relationship--28033ce2-a162-4888-89c9-3f9329e73c20",
#                 "relationship--0e09dc69-2fcc-4713-9d38-ad7f3c2f55f6",
#                 "relationship--4d093fec-4f08-42d4-9fbd-6c8a872680b4",
#                 "relationship--2efa665f-bd7c-49d7-93e0-be6f0ba382e7",
#                 "relationship--bfe1d480-51de-4fcd-9c20-9c083c19bf74",
#                 "relationship--2af4f6ef-c5a3-48e3-8204-8097bedb75a9",
#                 "relationship--405b7e51-cac1-422b-95a7-c1fa0cbb1fac",
#                 "relationship--d5298061-71e9-4b18-a1fd-834779fb27ad",
#                 "relationship--e2f6aaa8-2677-467e-bcd5-26e074b89c33",
#                 "relationship--cacddae4-ceb2-41f1-a96c-5eb0dd6d6b32",
#                 "relationship--2ae33812-d3b6-4050-8f8f-54e191758edd",
#                 "relationship--92a82420-4f37-4a86-906f-f95812963902",
#                 "relationship--64fe43a5-fa5a-4085-9678-90a296afec6e",
#                 "relationship--6dee46de-a63d-435d-9bc2-026d190d3431",
#                 "relationship--cfe15c22-7261-48ec-90f2-e733f626a59e",
#                 "relationship--1d883e51-2afd-4b25-910e-893b255e6270",
#                 "relationship--e60c06ee-8c9f-46ec-a3aa-d04b28498f0b",
#                 "relationship--721e41d3-8eb6-42a5-839d-fffd3a7d3fb4",
#                 "relationship--5de200eb-172d-45c1-924c-d4d9c6a3bd03",
#                 "relationship--ef091029-f092-477a-833b-344e25003666",
#                 "relationship--98623c6b-c40b-4f8b-9561-371e6c2478ba",
#                 "relationship--863984a5-1884-4beb-8fcb-118e203131ff",
#                 "relationship--4e0ea05a-8f7d-4315-bee6-9806a604782d",
#                 "relationship--d009095a-187e-4763-a80b-c3b9d8572519",
#                 "relationship--1be8f613-3904-4284-8ae2-edc6c59a2637",
#                 "relationship--7634b284-5779-484a-b93e-c0b50f861094",
#                 "relationship--e8ad1952-5e87-401f-9381-b505df829581",
#                 "relationship--127da9e5-8e32-4301-8528-f1ab99c1debd",
#                 "relationship--8d7e89ec-bea9-42f5-8a68-f0e5d1734ad5",
#                 "relationship--6d21f86a-7a78-46a9-a3de-bfd7fdb8da08",
#                 "relationship--d64c6d93-b744-4ef9-a12a-79cabf0a695d",
#                 "relationship--ffa0e751-3f25-458b-bf55-3b7fde928f58",
#                 "relationship--243b291b-5948-4f6d-917f-81e7b043c133",
#                 "relationship--0851bd55-0b5a-44a9-abc0-10c88b22b5b8",
#                 "relationship--2e252ef3-2bd6-45d0-a4ed-8a4e93a15bf9",
#                 "relationship--3888fca1-be53-414e-b502-f87e1703c83f",
#                 "relationship--6d60eb54-a971-423c-85be-07d1d9305de2",
#                 "relationship--72b4e21d-5c8e-450c-852c-c793bf68442d",
#                 "relationship--10398109-7b6c-48fd-a99b-6bebf9538209",
#                 "relationship--4b6d02e6-a3be-447c-8281-bd7b7b697480",
#                 "relationship--cd788344-5ddb-4461-883a-8bf8339e81d7",
#                 "relationship--4129003b-1d5d-400c-87fc-9562db926d3e",
#                 "relationship--2578524d-b341-403c-b4bd-8159b3b40e37",
#                 "relationship--ba49aab2-98fd-4eb1-a2d1-b80ffea0da92",
#                 "relationship--38750667-32bd-4c87-bf37-f4dfdf13d1f1",
#                 "relationship--837181f0-2047-4861-83fd-e26f38f8ce92",
#                 "relationship--83cc9fda-a9d6-4491-9f55-b51d3fb641a6",
#                 "relationship--126745bc-adc6-452a-9fbc-dbb6cf69b973",
#                 "relationship--04ce9130-f629-43ae-bfbd-e40b481503dc",
#                 "relationship--17bb4970-c166-47be-b84c-cac27162f60f",
#                 "relationship--b8d9450e-d15f-462a-8f41-c5b7356b679d",
#                 "relationship--a79e2848-4a12-417d-8ed2-6a7d632fd3be",
#                 "relationship--a9b8ac27-dd23-49f3-9e17-8c7fc17e6afe",
#                 "relationship--ad03d90f-1911-46f5-a9c3-d218e14ac9f5",
#                 "relationship--3981b189-1ecf-4729-ac02-d95a2e2859f9",
#                 "relationship--375ec973-d3db-40ec-ac54-5a6dbe131ad0",
#                 "relationship--37e0a60b-b7a4-4aa4-9652-2f1290e900e8",
#                 "relationship--5f627c4e-c3af-4a67-bb46-1dab28bd4a2b",
#                 "relationship--179a5f08-94a5-4c88-bcb7-bf260263f7d2",
#                 "relationship--7c38a096-b465-4c0c-b0c3-540d5b54c78e",
#                 "relationship--1d07741f-5666-4393-8bfd-a20a1e6ad5eb"
#             ],
#             "labels": [
#                 "Threat-Report",
#                 "misp:tool=\"MISP-STIX-Converter\""
#             ]
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--a2355290-e41e-5210-b03c-6ef88d4b61c2",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Create Localised Content\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Localised content refers to content that appeals to a specific community of individuals, often in defined geographic areas. An operation may create localised content using local language and dialects to resonate with its target audience and blend in with other local news and social media. Localised content may help an operation increase legitimacy, avoid detection, and complicate external attribution.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0101"
#                 ],
#                 "kill_chain": [
#                     "tactics:Microtarget"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0101.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Create Localised Content"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--9039269a-4975-52f8-92a8-f142978ffcef",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Develop Image-Based Content\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Creating and editing false or misleading visual artefacts, often aligned with one or more specific narratives, for use in a disinformation campaign. This may include photographing staged real-life situations, repurposing existing digital images, or using image creation and editing technologies.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0086"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0086.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Develop Image-Based Content"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--7bbdfe14-8294-54f7-9842-449f2db17a90",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Develop Inauthentic News Articles\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | An influence operation may develop false or misleading news articles aligned to their campaign goals or narratives.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0085.003"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0085.003.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Develop Inauthentic News Articles"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--bff9c590-c655-5c15-ae4d-13d353a0d9a4",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Develop Text-Based Content\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Creating and editing false or misleading text-based artefacts, often aligned with one or more specific narratives, for use in a disinformation campaign.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0085"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0085.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Develop Text-Based Content"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--7828596a-f1b5-563c-bd40-4a876b5cec58",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Reuse Existing Content\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | When an operation recycles content from its own previous operations or plagiarises from external operations. An operation may launder information to conserve resources that would have otherwise been utilised to develop new content.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0084"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0084.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Reuse Existing Content"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--d9bbfde8-dda3-5f20-a9ed-fbf021ecd8c1",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Segment Audiences\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Create audience segmentations by features of interest to the influence campaign, including political affiliation, geographic location, income, demographics, and psychographics.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0072"
#                 ],
#                 "kill_chain": [
#                     "tactics:Target Audience Analysis"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0072.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Segment Audiences"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--4896a448-be51-5423-89cd-efb6444b1c75",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Develop New Narratives\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Actors may develop new narratives to further strategic or tactical goals, especially when existing narratives adequately align with the campaign goals. New narratives provide more control in terms of crafting the message to achieve specific goals. However, new narratives may require more effort to disseminate than adapting or adopting existing narratives.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0082"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Narratives"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0082.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Develop New Narratives"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--f1d52ce1-f431-5732-a071-215cb3306f3e",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Leverage Conspiracy Theory Narratives\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | \"Conspiracy narratives\" appeal to the human desire for explanatory order, by invoking the participation of poweful (often sinister) actors in pursuit of their own political goals. These narratives are especially appealing when an audience is low-information, marginalised or otherwise inclined to reject the prevailing explanation. Conspiracy narratives are an important component of the \"firehose of falsehoods\" model.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0022"
#                 ],
#                 "kill_chain": [
#                     "tactics:Develop Narratives"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0022.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Leverage Conspiracy Theory Narratives"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--b9dceeab-f5d8-50ae-ad8a-365d77fc4a3d",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Create Inauthentic News Sites\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Create Inauthentic News Sites",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0098.001"
#                 ],
#                 "kill_chain": [
#                     "tactics:Establish Legitimacy"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0098.001.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Create Inauthentic News Sites"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "pattern": "[domain-name:value = '0enebnews.ga']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T15:52:07Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "Network activity"
#                 }
#             ],
#             "labels": [
#                 "misp:type=\"domain\"",
#                 "misp:category=\"Network activity\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--2daab435-3a94-4508-b085-eb25f3df06a3",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:52:06.000Z",
#             "modified": "2024-06-07T15:52:06.000Z",
#             "pattern": "[domain-name:value = '7sabah.com.tr']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T15:52:06Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "Network activity"
#                 }
#             ],
#             "labels": [
#                 "misp:type=\"domain\"",
#                 "misp:category=\"Network activity\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--1df640d4-465e-436d-a195-2ef830bac6dd",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "pattern": "[(network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '5.9.200.236') AND (network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '78.46.102.123') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = '7sabah.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ftp.7sabah.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'mail.7sabah.com')]",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T15:52:07Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "network"
#                 }
#             ],
#             "labels": [
#                 "misp:name=\"ip-port\"",
#                 "misp:meta-category=\"network\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "x-misp-object",
#             "spec_version": "2.1",
#             "id": "x-misp-object--531e2764-4e78-414f-8111-baec812fdbc0",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:32:13.000Z",
#             "modified": "2024-06-07T15:32:13.000Z",
#             "labels": [
#                 "misp:name=\"whois\"",
#                 "misp:meta-category=\"network\""
#             ],
#             "x_misp_attributes": [
#                 {
#                     "type": "whois-registrant-name",
#                     "object_relation": "registrant-name",
#                     "value": "Aydin Altay",
#                     "category": "Attribution",
#                     "uuid": "0e280ba9-0f92-4ce9-8d1a-7c7a5ce3fdb3"
#                 }
#             ],
#             "x_misp_meta_category": "network",
#             "x_misp_name": "whois"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--38005a75-0d99-449c-b7de-8a8e7cdae262",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:50:46.000Z",
#             "modified": "2024-06-07T15:50:46.000Z",
#             "pattern": "[(network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '5.9.200.236') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = '7sabah.net') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ftp.7sabah.net')]",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T15:50:46Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "network"
#                 }
#             ],
#             "labels": [
#                 "misp:name=\"ip-port\"",
#                 "misp:meta-category=\"network\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--5e4718d5-1e48-4447-a36d-a3d073898292",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T15:50:46.000Z",
#             "modified": "2024-06-07T15:50:46.000Z",
#             "pattern": "[(network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '5.9.200.236') AND (network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '78.46.102.123') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = '7sabah.org') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ftp.7sabah.org') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ns.7sabah.org')]",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T15:50:46Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "network"
#                 }
#             ],
#             "labels": [
#                 "misp:name=\"ip-port\"",
#                 "misp:meta-category=\"network\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--7f984091-41b3-5e8f-b723-1d5eb9150d1d",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Create Personas\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Creating fake people, often with accounts across multiple platforms. These personas can be as simple as a name, can contain slightly more background like location, profile pictures, backstory, or can be effectively backstopped with indicators like fake identity documents.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0097"
#                 ],
#                 "kill_chain": [
#                     "tactics:Establish Legitimacy"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0097.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Create Personas"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--79364323-1d9e-5e29-8bd8-d0bc7bf32f30",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Mainstream Social Networks\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Examples include Facebook, Twitter, LinkedIn, etc.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0104.001"
#                 ],
#                 "kill_chain": [
#                     "tactics:Select Channels and Affordances"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0104.001.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Mainstream Social Networks"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--012be2cf-7aed-5ac4-8fb5-ad7ffff73ea0",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Social Networks\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Social media are interactive digital channels that facilitate the creation and sharing of information, ideas, interests, and other forms of expression through virtual communities and networks.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0104"
#                 ],
#                 "kill_chain": [
#                     "tactics:Select Channels and Affordances"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0104.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Social Networks"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--324248a7-3a0c-5689-8f0e-770d6d6f2dd7",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Cross-Posting\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Cross-posting refers to posting the same message to multiple internet discussions, social media platforms or accounts, or news groups at one time. An influence operation may post content online in multiple communities and platforms to increase the chances of content exposure to the target audience.",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0119"
#                 ],
#                 "kill_chain": [
#                     "tactics:Maximise Exposure"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0119.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Cross-Posting"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--e41d7f0f-d913-5973-b8a3-385b39e78ebd",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Post Content\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Delivering content by posting via owned media (assets that the operator controls).",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0115"
#                 ],
#                 "kill_chain": [
#                     "tactics:Deliver Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0115.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Post Content"
#         },
#         {
#             "type": "x-misp-galaxy-cluster",
#             "spec_version": "2.1",
#             "id": "x-misp-galaxy-cluster--9c655aa6-1474-5ab9-8eff-519df00fe41b",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "labels": [
#                 "misp:galaxy-name=\"Techniques\"",
#                 "misp:galaxy-type=\"disarm-techniques\"",
#                 "misp-galaxy:disarm-techniques=\"Social Media\""
#             ],
#             "x_misp_description": "DISARM is a framework designed for describing and understanding disinformation incidents. | Social Media",
#             "x_misp_meta": {
#                 "external_id": [
#                     "T0114.001"
#                 ],
#                 "kill_chain": [
#                     "tactics:Deliver Content"
#                 ],
#                 "refs": [
#                     "https://github.com/DISARMFoundation/DISARMframeworks/blob/main/generated_pages/techniques/T0114.001.md"
#                 ]
#             },
#             "x_misp_name": "Techniques",
#             "x_misp_type": "disarm-techniques",
#             "x_misp_value": "Social Media"
#         },
#         {
#             "type": "observed-data",
#             "spec_version": "2.1",
#             "id": "observed-data--999a81ab-f568-431a-98e7-c110a3005ec9",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "first_observed": "2024-06-07T16:25:13Z",
#             "last_observed": "2024-06-07T16:25:13Z",
#             "number_observed": 1,
#             "object_refs": [
#                 "user-account--999a81ab-f568-431a-98e7-c110a3005ec9"
#             ],
#             "labels": [
#                 "misp:name=\"facebook-account\"",
#                 "misp:meta-category=\"misc\"",
#                 "misp:to_ids=\"False\""
#             ]
#         },
#         {
#             "type": "user-account",
#             "spec_version": "2.1",
#             "id": "user-account--999a81ab-f568-431a-98e7-c110a3005ec9",
#             "account_login": "maria Lopez",
#             "account_type": "facebook",
#             "x_misp_attachment": "1.jpeg",
#             "x_misp_description": "Maria Lopez \u2013 Impersonates a woman of French nationality. This account promotes the European fake media\r\noutlet \"AWD news\"."
#         },
#         {
#             "type": "observed-data",
#             "spec_version": "2.1",
#             "id": "observed-data--9a94542d-3b31-4fe4-821a-b9b44020f047",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:25:13.000Z",
#             "modified": "2024-06-07T16:25:13.000Z",
#             "first_observed": "2024-06-07T16:25:13Z",
#             "last_observed": "2024-06-07T16:25:13Z",
#             "number_observed": 1,
#             "object_refs": [
#                 "user-account--9a94542d-3b31-4fe4-821a-b9b44020f047"
#             ],
#             "labels": [
#                 "misp:name=\"twitter-account\"",
#                 "misp:meta-category=\"misc\"",
#                 "misp:to_ids=\"False\""
#             ]
#         },
#         {
#             "type": "user-account",
#             "spec_version": "2.1",
#             "id": "user-account--9a94542d-3b31-4fe4-821a-b9b44020f047",
#             "account_login": "Sopie_alvarez23",
#             "account_type": "twitter",
#             "x_misp_followers": "4",
#             "x_misp_following": "41",
#             "x_misp_likes": "33",
#             "x_misp_private": "False",
#             "x_misp_tweets": "3248"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--1556485a-a0e6-47cb-9aa5-c799f09989c5",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:26:51.000Z",
#             "modified": "2024-06-07T16:26:51.000Z",
#             "pattern": "[(network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '5.9.200.236') AND (network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '67.205.99.12') AND (network-traffic:dst_ref.type = 'ipv4-addr' AND network-traffic:dst_ref.value = '78.46.102.123') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'analytics.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'de.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'es.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'fr.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ftp.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'it.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ns1.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ns2.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'po.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'ru.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'tr.awdnews.com') AND (network-traffic:dst_ref.type = 'domain-name' AND network-traffic:dst_ref.value = 'webmail.awdnews.com')]",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2024-06-07T16:26:51Z",
#             "kill_chain_phases": [
#                 {
#                     "kill_chain_name": "misp-category",
#                     "phase_name": "network"
#                 }
#             ],
#             "labels": [
#                 "misp:name=\"ip-port\"",
#                 "misp:meta-category=\"network\"",
#                 "misp:to_ids=\"True\""
#             ]
#         },
#         {
#             "type": "x-misp-object",
#             "spec_version": "2.1",
#             "id": "x-misp-object--27696487-d5c8-4706-9513-f911bdad923f",
#             "created_by_ref": "identity--7ca79a22-44da-4b49-8cd8-850887b2e389",
#             "created": "2024-06-07T16:25:42.000Z",
#             "modified": "2024-06-07T16:25:42.000Z",
#             "labels": [
#                 "misp:name=\"whois\"",
#                 "misp:meta-category=\"network\""
#             ],
#             "x_misp_attributes": [
#                 {
#                     "type": "whois-registrant-name",
#                     "object_relation": "registrant-name",
#                     "value": "Bayan Kelvin Middelkoop",
#                     "category": "Attribution",
#                     "uuid": "8dc01686-8b3e-4ac8-8e79-b80acd64abec"
#                 }
#             ],
#             "x_misp_meta_category": "network",
#             "x_misp_name": "whois"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--e290f2e3-1043-4456-8eb8-7fcde31372d7",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "target_ref": "x-misp-galaxy-cluster--a2355290-e41e-5210-b03c-6ef88d4b61c2"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--c1b67dba-5904-4d8b-a012-a6aa3fd84897",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "target_ref": "x-misp-galaxy-cluster--9039269a-4975-52f8-92a8-f142978ffcef"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--81954bde-3f01-4d21-b3f9-b1abd07c191d",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "target_ref": "x-misp-galaxy-cluster--7bbdfe14-8294-54f7-9842-449f2db17a90"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--241a05e8-47d4-40cf-9c8d-a9a0eaeba563",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "target_ref": "x-misp-galaxy-cluster--bff9c590-c655-5c15-ae4d-13d353a0d9a4"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--a9ab0538-107c-44d5-9888-df9cfddb7c8c",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref": "indicator--40b40ac5-2408-47aa-83eb-a0db1647e023",
#             "target_ref": "x-misp-galaxy-cluster--7828596a-f1b5-563c-bd40-4a876b5cec58"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--7e97649d-ec2b-4526-ba89-dca02fcf715a",
#             "created": "2024-06-07T15:52:07.000Z",
#             "modified": "2024-06-07T15:52:07.000Z",
#             "relationship_type": "related-to",
#             "source_ref":

#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--179a5f08-94a5-4c88-bcb7-bf260263f7d2",
#             "created": "2024-06-07T16:26:38.000Z",
#             "modified": "2024-06-07T16:26:38.000Z",
#             "relationship_type": "delivered-by",
#             "source_ref": "indicator--1556485a-a0e6-47cb-9aa5-c799f09989c5",
#             "target_ref": "observed-data--999a81ab-f568-431a-98e7-c110a3005ec9"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--7c38a096-b465-4c0c-b0c3-540d5b54c78e",
#             "created": "2024-06-07T16:26:51.000Z",
#             "modified": "2024-06-07T16:26:51.000Z",
#             "relationship_type": "delivered-by",
#             "source_ref": "indicator--1556485a-a0e6-47cb-9aa5-c799f09989c5",
#             "target_ref": "observed-data--9a94542d-3b31-4fe4-821a-b9b44020f047"
#         },
#         {
#             "type": "relationship",
#             "spec_version": "2.1",
#             "id": "relationship--1d07741f-5666-4393-8bfd-a20a1e6ad5eb",
#             "created": "2024-06-07T16:25:42.000Z",
#             "modified": "2024-06-07T16:25:42.000Z",
#             "relationship_type": "owner-of",
#             "source_ref": "x-misp-object--27696487-d5c8-4706-9513-f911bdad923f",
#             "target_ref": "indicator--1556485a-a0e6-47cb-9aa5-c799f09989c5"
#         }
#     ]
# }

# %% [markdown]
# ## Modifica dello stix

# %%
import re
def extract_name_from_labels(labels):
    for label in labels:
        match = re.match(r'misp:name="([^"]+)"', label)
        if match:
            return match.group(1)
    return None

def modify_stix_data(stix_data):
    if stix_data is not None:
        for obj in stix_data.get('objects', []):
            # Modifica oggetti di tipo "x-misp-galaxy-cluster"
            if obj.get('type') == 'x-misp-galaxy-cluster':
                obj['type'] = 'attack-pattern'
                obj['name'] = f"DISARM TTP - {obj.get('x_misp_value', '')}"

            # Modifica oggetti di tipo "observed-data"
            elif obj.get('type') == 'observed-data':
                obj['name'] = extract_name_from_labels(obj.get('labels', []))

            # Modifica oggetti di tipo "user-account"
            elif obj.get('type') == 'user-account':
                obj['name'] = obj.get('account_login', '')

            # Modifica oggetti di tipo "x-misp-object" con "x_misp_name: whois"
            elif obj.get('type') == 'x-misp-object' and obj.get('x_misp_name') == 'whois':
                obj['type'] = 'threat-actor'

            # Modifica oggetti di tipo "indicator" con "misp:name: ip-port"
            elif obj.get('type') == 'indicator':
                labels = obj.get('labels', [])
                if 'misp:name="ip-port"' or 'misp:type="domain"' in labels:
                    obj['name'] = 'Domain'
    else:
        print("Nessun dato da modificare.")
    return stix_data


def write_stix_json(file_path, data):
    try:
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4)
    except Exception as e:
        print(f"Errore nella scrittura del file: {e}")

# %% [markdown]
# ## Esecuzione delle funzioni

# %%
input_file_path = '/content/IranianDisinformation.json'  # Sostituisci con il percorso del tuo file JSON STIX
output_file_path = '/content/IranianDisinformationClear.json'  # Sostituisci con il percorso dove salvare il file modificato

stix_data = read_stix_json(input_file_path)
modified_stix_data = modify_stix_data(stix_data)
write_stix_json(output_file_path, modified_stix_data)
print(f"File modificato salvato in: {output_file_path}")
# Out:
# File modificato salvato in: /content/IranianDisinformationClear.json
